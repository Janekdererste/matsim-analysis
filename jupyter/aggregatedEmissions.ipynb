# %%
import pandas
import matplotlib.pyplot as plt

plt.style.use('ggplot')

# %%
df = pandas.read_csv("C:\\Users\\Janekdererste\\Desktop\\deurb\\total-emissions.csv", delimiter=',', index_col='Run')
df
# Out:
#                                         CO     CO2_TOTAL            FC  \
# Run
# deurbanisation-10pct-matches  2.031698e+06  1.500390e+08  4.954538e+07
# deurbanisation-20pct-matches  2.138531e+06  1.606615e+08  5.297357e+07
# deurbanisation-30pct-matches  2.267487e+06  1.736873e+08  5.716666e+07
# deurbanisation-40pct-matches  2.355716e+06  1.825399e+08  6.002529e+07
# deurbanisation-50pct-matches  2.463981e+06  1.935428e+08  6.357237e+07
# deurbanisation-60pct-matches  2.551799e+06  2.030200e+08  6.661980e+07
# deurbanisation-70pct-matches  2.640394e+06  2.120871e+08  6.954313e+07
# deurbanisation-80pct-matches  2.695151e+06  2.185476e+08  7.161794e+07
# deurbanisation-90pct-matches  2.794651e+06  2.295493e+08  7.516098e+07
# baseCase                      2.500129e+06  1.840411e+08  6.085308e+07
#
#                                          HC           NMHC            NOx  \
# Run
# deurbanisation-10pct-matches  246016.185542  231525.957847  461045.407013
# ...

# %%
df["CO2_TOTAL"].plot.bar(figsize=(20,9), title='Cumulated CO2 Emissions [g]')
# Out:
# <AxesSubplot:title={'center':'Cumulated CO2 Emissions [g]'}, xlabel='Run'>
